# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import KFold

# %%
df=pd.read_csv(r'C:\Users\yatharth bansal\Downloads\nba_2013.csv')

# %%
df.head()
# Out:
#           player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  ...  \
# 0     Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468  ...
# 1   Steven Adams   C   20          OKC  81  20  1197   93   185  0.503  ...
# 2    Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520  ...
# 3  Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459  ...
# 4  Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546  ...
#
#    drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 0  144  216   28   23   26   30  122   171  2013-2014        2013
# 1  190  332   43   40   57   71  203   265  2013-2014        2013
# 2  204  306   38   24   36   39  108   362  2013-2014        2013
# 3  230  262  248   35    3  146  136  1330  2013-2014        2013
# 4  183  277   40   23   46   63  187   328  2013-2014        2013
#
# [5 rows x 31 columns]

# %% [markdown]
# Removing useless columns.

# %%
df.drop(columns=['player','pos','bref_team_id','season','season_end'],inplace=True)

# %%
df.head()
# Out:
#    age   g  gs    mp   fg   fga    fg.  x3p  x3pa      x3p.  ...    ft.  orb  \
# 0   23  63   0   847   66   141  0.468    4    15  0.266667  ...  0.660   72
# 1   20  81  20  1197   93   185  0.503    0     0       NaN  ...  0.581  142
# 2   27  53  12   961  143   275  0.520    0     0       NaN  ...  0.639  102
# 3   28  73  73  2552  464  1011  0.459  128   300  0.426667  ...  0.815   32
# 4   25  56  30   951  136   249  0.546    0     1  0.000000  ...  0.836   94
#
#    drb  trb  ast  stl  blk  tov   pf   pts
# 0  144  216   28   23   26   30  122   171
# 1  190  332   43   40   57   71  203   265
# 2  204  306   38   24   36   39  108   362
# 3  230  262  248   35    3  146  136  1330
# 4  183  277   40   23   46   63  187   328
#
# [5 rows x 26 columns]

# %%
df.describe()
# Out:
#               age           g          gs           mp          fg  \
# count  481.000000  481.000000  481.000000   481.000000  481.000000
# mean    26.509356   53.253638   25.571726  1237.386694  192.881497
# std      4.198265   25.322711   29.658465   897.258840  171.832793
# min     19.000000    1.000000    0.000000     1.000000    0.000000
# 25%     23.000000   32.000000    0.000000   388.000000   47.000000
# 50%     26.000000   61.000000   10.000000  1141.000000  146.000000
# 75%     29.000000   76.000000   54.000000  2016.000000  307.000000
# max     39.000000   83.000000   82.000000  3122.000000  849.000000
#
#                fga         fg.         x3p        x3pa        x3p.  ...  \
# count   481.000000  479.000000  481.000000  481.000000  414.000000  ...
# mean    424.463617    0.436436   39.613306  110.130977    0.285111  ...
# std     368.850833    0.098672   50.855639  132.751732    0.157633  ...
# min       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %%
df.columns
# Out:
# Index(['age', 'g', 'gs', 'mp', 'fg', 'fga', 'fg.', 'x3p', 'x3pa', 'x3p.',
#        'x2p', 'x2pa', 'x2p.', 'efg.', 'ft', 'fta', 'ft.', 'orb', 'drb', 'trb',
#        'ast', 'stl', 'blk', 'tov', 'pf', 'pts'],
#       dtype='object')

# %%
df[['x2p', 'x2pa', 'x2p.', 'efg.', 'ft', 'fta']].describe()
# Out:
#               x2p         x2pa        x2p.        efg.          ft         fta
# count  481.000000   481.000000  478.000000  479.000000  481.000000  481.000000
# mean   153.268191   314.332640    0.466947    0.480752   91.205821  120.642412
# std    147.223161   294.174554    0.104448    0.099552  103.667725  131.240639
# min      0.000000     0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     31.000000    67.000000    0.434719    0.451000   16.000000   22.000000
# 50%    110.000000   227.000000    0.474475    0.488000   53.000000   73.000000
# 75%    230.000000   459.000000    0.513729    0.526000  126.000000  179.000000
# max    706.000000  1408.000000    1.000000    1.000000  703.000000  805.000000

# %% [markdown]
# Removing missing values.

# %%
df['fg.']=df['fg.'].fillna(df['fg.'].mean())
df['x3p.']=df['x3p.'].fillna(df['x3p.'].mean())
df['ft.']=df['ft.'].fillna(df['ft.'].mean())
df['x2p.']=df['x2p.'].fillna(df['x2p.'].mean())
df['efg.']=df['efg.'].fillna(df['efg.'].mean())

# %%
df.describe()
# Out:
#               age           g          gs           mp          fg  \
# count  481.000000  481.000000  481.000000   481.000000  481.000000
# mean    26.509356   53.253638   25.571726  1237.386694  192.881497
# std      4.198265   25.322711   29.658465   897.258840  171.832793
# min     19.000000    1.000000    0.000000     1.000000    0.000000
# 25%     23.000000   32.000000    0.000000   388.000000   47.000000
# 50%     26.000000   61.000000   10.000000  1141.000000  146.000000
# 75%     29.000000   76.000000   54.000000  2016.000000  307.000000
# max     39.000000   83.000000   82.000000  3122.000000  849.000000
#
#                fga         fg.         x3p        x3pa        x3p.  ...  \
# count   481.000000  481.000000  481.000000  481.000000  481.000000  ...
# mean    424.463617    0.436436   39.613306  110.130977    0.285111  ...
# std     368.850833    0.098467   50.855639  132.751732    0.146218  ...
# min       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %% [markdown]
# Dividing our dataset.

# %%
X=df.drop(columns='pts')
y=df['pts']

# %% [markdown]
# Scaling our dataset.

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=.30,random_state=355)

# %% [markdown]
# Creating a model of knn regressor.

# %%
knn=KNeighborsRegressor()
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
knn.score(X_test,y_test)
# Out:
# 0.9680125291271934

# %% [markdown]
# Using grid search CV for tuning our model.

# %%
param_grid = { 'algorithm' : ['ball_tree', 'kd_tree', 'brute'],
               'leaf_size' : [25,27,30,32,34],
               'n_neighbors' : [3,5,7,9,10]
              }

# %%
gridsearch = GridSearchCV(knn, param_grid,verbose=3)

# %%
gridsearch.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 75 candidates, totalling 225 fits
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.945, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.953, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# ...

# %%
gridsearch.best_params_
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 25, 'n_neighbors': 3}

# %%
knn=KNeighborsRegressor(algorithm= 'ball_tree', leaf_size= 25, n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='ball_tree', leaf_size=25, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')

# %%
knn.score(X_test,y_test)
# Out:
# 0.9552729531943484
